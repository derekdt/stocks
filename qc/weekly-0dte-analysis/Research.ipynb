// %% [markdown]
// ![QuantConnect Logo](https://cdn.quantconnect.com/web/i/icon.png)
// <hr>

// %%
// We need to load assemblies at the start in their own cell
#load "../Initialize.csx"

// %%
// QuantBook C# Research Environment
// For more information see https://www.quantconnect.com/docs/v2/our-platform/research/getting-started
#load "../QuantConnect.csx"

using QuantConnect;
using QuantConnect.Data;
using QuantConnect.Research;
using QuantConnect.Algorithm;

var qb = new QuantBook();
// Locally Lean installs free sample data, to download more data please visit https://www.quantconnect.com/docs/v2/lean-cli/datasets/downloading-data 

// Add QQQ equity
var qqq = qb.AddEquity("QQQ");

// Define start and end dates
var startDate = new DateTime(2020, 1, 1);
var endDate = new DateTime(2024, 12, 31);

// Get historical weekly bars for QQQ
var history = qb.History(qqq.Symbol, startDate, endDate, Resolution.Weekly);

// %%
// Display first 5 weekly bars
foreach (var bar in history.Take(5)) {
    Console.WriteLine($"Date: {bar.Time}, Open: {bar.Open}, High: {bar.High}, Low: {bar.Low}, Close: {bar.Close}, Volume: {bar.Volume}");
}

// Display total number of weekly bars
Console.WriteLine($"\nTotal weekly bars: {history.Count()}");
